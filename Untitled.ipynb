# %%
import numpy as N
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import sliced_corr_bias

# %%
reload(sliced_corr_bias)
# Out:
# <module 'sliced_corr_bias' from 'sliced_corr_bias.py'>

# %%
rr=N.arange(1.0, 200.0, 1.0)

# %%
pklin=N.loadtxt("/Users/nuala/Documents/Research/pktmp.txt")

# %%
xilin=sliced_corr_bias.xilin_from_pklin(rr, pklin=pklin, smw=3.0)
sigma=N.sqrt(sliced_corr_bias.xilin_from_pklin(N.array([0.0]), pklin=pklin, smw=3.0))
# Out:
# sliced_corr_bias.py:16: RuntimeWarning: invalid value encountered in divide
#   jrk=N.sin(rkk)/rkk

# %%
plt.style.use('nuala')

# %%
plt.plot(rr, rr**2*xilin)

# %%
logd=N.linspace(-5, 5, 50)
dh0=N.exp(logd)-1.0

# %%
reload(sliced_corr_bias)
# Out:
# <module 'sliced_corr_bias' from 'sliced_corr_bias.py'>

# %%
ah0, aa0=sliced_corr_bias.compute_xird(dh0, xilin, sigma, sliced_corr_bias.delta_h, (1.2, 0.0, 0.0), bins='log')

# %%
dahdam2=sliced_corr_bias.dahdam(dm0, 0.87959912636, 1.2, 0.0, 0.0)

# %%
plt.scatter(ah0, aa0)

# %%
plt.plot(ah0[1:], N.diff(ah0)/N.diff(aa0))

# %%
import scipy.misc as M
from scipy.interpolate import InterpolatedUnivariateSpline

# %%
dahdam=InterpolatedUnivariateSpline(aa0, ah0, k=1)

# %%
dd=M.derivative(dahdam, aa0, dx=1e-5)

# %%
plt.plot(aa0, dd)
